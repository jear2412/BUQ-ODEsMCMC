# %%
import numpy as np
import glob
from PTMCMCSampler import PTMCMCSampler

import scipy
import scipy.stats

import seaborn as sns
import matplotlib.pyplot as plt

from numba import jit
from matplotlib import cm
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions

import timeit

# %%
def ClassMatrix(x, means):
    temp = np.zeros( shape=(x.shape[0], means.shape[0]) )
    #q = 9.21034 / 100
    for i in range( x.shape[0]):
        temp2=np.zeros( means.shape[0] )
        for j in range( means.shape[0] ):
            temp2[j] =np.dot( x[i] - means[j], x[i] - means[j] )
        index_min = np.argmin(temp2 )
        temp[i][index_min]=1
    return temp

#estimation of weights
def weights(x, means, size):
    #take a sample of size=size and calculate the weights
    indexes = np.random.choice( np.arange( 0, len(x) ), size=size, replace=False )
    temp=ClassMatrix(x[indexes], means)
    return np.mean(temp, 0)


def AFER( fw, tw):
    '''Average frecuency error rate 
    fw: frequency weight
    tw: true weight 
    Calculate \sum| fw-tw | '''
    return np.sum( np.abs(  fw-tw ) )
    

def fpoints(f, args, theta,  pars , lb, upb, m=100):
    '''f is the objective function to be plotted
       args are the arguments of f as a list
       theta is the vector of true parameters
       pars are the parameters to be plotted (passed as an array)
       lb: array of lower bounds
       upb: array of upper bounds
       '''
       
    xx = np.linspace(lb[0], upb[0], m)
    yy = np.linspace(lb[1], upb[1], m)
    xx, yy = np.meshgrid(xx, yy)
    Z = np.zeros(shape=[m, m])

    for i in range( m ):
        for j in range( m ):
            temp=np.array( [xx[i][j], yy[i][j]] )
            Z[i][j] = f( temp )
    return xx,yy,Z 

def pContour(xx,yy,Z,c=100):
    plt.contour( xx, yy, Z, c, colors='b' )
    plt.xlabel( r'$\theta_1$' )
    plt.ylabel( r'$\theta_2$' )
    plt.title( r'Objective Function Contours' )
    plt.show()    

# log target f(x) case b

def logf(x):
    if(x[0]>0 and x[0]>0 and x[0]<10 and x[1]<10   ):
      w = 1/np.sqrt(np.sum(np.square((mu-[5,5])),1))
      v = np.sqrt(np.sum(np.square((mu-[5,5])),1))/20
      return np.log(np.sum((w/v)*np.exp(-1.0/(2.0*v)*np.sum(np.square(x-mu),1))))
    else:
      return -np.inf 

def Analysis(x):
    mean=np.mean(x,0)
    var=np.var(x,0)

    ess1 = tfp.mcmc.effective_sample_size(  x[:,0] , filter_beyond_positive_pairs=True)
    ess2 = tfp.mcmc.effective_sample_size(  x[:,1] , filter_beyond_positive_pairs=True)

    ess=min(ess1, ess2)    

    summary= {
        "Mean": mean,
        "Variance": var,
        "mVar": var/ess,
        "ess": ess,
        }
    return summary

# %%
class PT_target(object):
    
    
    def logL(self,x):
      if(x[0]>0 and x[0]>0 and x[0]<10 and x[1]<10   ):
        w = (1.0 / num_mixtures) * np.ones( num_mixtures )
        v = 1.0 / (10.0) * np.ones( num_mixtures )
        return np.log( np.sum( (w / v ** 2) * np.exp( -1.0 / (2.0 * v ** 2) * np.sum( np.square( x - mu ), 1 ) ) ) )
      else:
        return -np.inf 
    
    def log_prior(self, x):
        return 0

# %%
mu = np.array(
    [[2.18, 5.76], [8.67, 9.59], [4.24, 8.48], [8.41, 1.68], [3.93, 8.82], [3.25, 3.47], [1.70, 0.50], [4.59, 5.60],
     [6.91, 5.81], [6.87, 5.40], [5.41, 2.65], [2.70, 7.88], [4.98, 3.70], [1.14, 2.39], [8.33, 9.50], [4.93, 1.5],
     [1.83, 0.09], [2.26, 0.31], [5.54, 6.86], [1.69, 8.11]] )

num_mixtures = 20 #number of mixture components
dim = 2  # mixture of bivariate Gaussians

# %%
f=PT_target()
cov=np.diag([ 1,1])
real_weights=np.zeros(20)
for i in range(20):
  real_weights[i]=1/(  np.sqrt( np.dot(mu[i]-np.array([5,5]),mu[i]-np.array([5,5]))    )   )


real_weights=real_weights/np.sum(real_weights)
print(real_weights)
# Out:
# [0.04579808 0.02276038 0.03755132 0.02810495 0.0337176  0.05754243
#  0.02396969 0.18406182 0.06447266 0.06994638 0.05607158 0.03629122
#  0.10287907 0.02870615 0.02389351 0.03820911 0.02288663 0.02462541
#  0.06906161 0.02945039]

# %%
M=50
T=50000
bi=int(T*0.15)

AFERhatPT=np.zeros(M)
ndisModesPT=np.zeros(M)
hatIATPT=np.zeros(M)

sample_PT1=np.zeros([ T-1000, M ])
sample_PT2=np.zeros([ T-1000, M ])
times=np.zeros(M)


for i in range(M):
    print('ITERATION: ', i)
    sampler = PTMCMCSampler.PTSampler(dim, f.logL , f.log_prior, np.copy(cov), outDir='PTcaseB/chains', resume=False)
    p0=scipy.stats.uniform.rvs(0,10,2)
 
    
   
    a=timeit.timeit()
    sampler.sample(p0, T, burn= bi  , thin=1, covUpdate=500,
               SCAMweight=30, AMweight=20, DEweight=50, HMCweight=0, HMCsteps=0)
   
    b=timeit.timeit()
    times[i]=b-a
    
    data = np.loadtxt('PTcaseB/chains/chain_1.txt') #if T is changed be sure to create new directory for chain
    PTchain = data[:,:-4]
    
    ssize=PTchain[ bi:,0:2].shape[0]
    print('Calculating weights for iteration: ', i)
    ws_t=weights( PTchain[ bi:,0:2], means= mu, size= ssize )
    
    ndisModesPT[i]=np.sum(ws_t>0)
    
    print('Calculating ess for iteration: ', i)
    ess1 = tfp.mcmc.effective_sample_size(  PTchain[bi:,0] , filter_beyond_positive_pairs=True)
    ess2 = tfp.mcmc.effective_sample_size(  PTchain[bi:,1] , filter_beyond_positive_pairs=True)

    ess=min(ess1, ess2)    
    
    hatIATPT[i]=ess
    
    sample_PT1[:,i]= PTchain[:,0]
    sample_PT2[:,i]= PTchain[:,1]
    
    AFERhatPT[i]=AFER(ws_t, real_weights )
# Out:
# ITERATION:  0
# <ipython-input-23-ef22395194b8>:8: RuntimeWarning: divide by zero encountered in log
#   return np.log( np.sum( (w / v ** 2) * np.exp( -1.0 / (2.0 * v ** 2) * np.sum( np.square( x - mu ), 1 ) ) ) )
# Finished 14.00 percent in 1.933675 s Acceptance rate = 0.891286Adding DE jump with weight 50
# Finished 98.00 percent in 13.050069 s Acceptance rate = 0.392918
# Run Complete
# Calculating weights for iteration:  0
# Calculating ess for iteration:  0
# ITERATION:  1
# Finished 14.00 percent in 1.744244 s Acceptance rate = 0.889429Adding DE jump with weight 50
# Finished 98.00 percent in 12.456951 s Acceptance rate = 0.410102
# Run Complete
# Calculating weights for iteration:  1
# Calculating ess for iteration:  1
# ITERATION:  2
# Finished 14.00 percent in 1.921660 s Acceptance rate = 0.410143Adding DE jump with weight 50
# Finished 98.00 percent in 11.906523 s Acceptance rate = 0.195041
# Run Complete
# Calculating weights for iteration:  2
# Calculating ess for iteration:  2
# ITERATION:  3
# Finished 14.00 percent in 1.593952 s Acceptance rate = 0.0642857Adding DE jump with weight 50
# Finished 98.00 percent in 10.430528 s Acceptance rate = 0.0633333
# Run Complete
# Calculating weights for iteration:  3
# Calculating ess for iteration:  3
# ITERATION:  4
# Finished 14.00 percent in 1.818369 s Acceptance rate = 0.936857Adding DE jump with weight 50
# Finished 98.00 percent in 11.882884 s Acceptance rate = 0.810531
# Run Complete
# Calculating weights for iteration:  4
# Calculating ess for iteration:  4
# ITERATION:  5
# Finished 14.00 percent in 1.640607 s Acceptance rate = 0.330286Adding DE jump with weight 50
# Finished 98.00 percent in 11.415876 s Acceptance rate = 0.182816
# Run Complete
# Calculating weights for iteration:  5
# Calculating ess for iteration:  5
# ITERATION:  6
# Finished 14.00 percent in 1.708655 s Acceptance rate = 0.322429Adding DE jump with weight 50
# Finished 98.00 percent in 11.045996 s Acceptance rate = 0.332958
# Run Complete
# Calculating weights for iteration:  6
# Calculating ess for iteration:  6
# ITERATION:  7
# Finished 14.00 percent in 1.566430 s Acceptance rate = 0.934857Adding DE jump with weight 50
# Finished 98.00 percent in 11.450922 s Acceptance rate = 0.773633
# Run Complete
# Calculating weights for iteration:  7
# Calculating ess for iteration:  7
# ITERATION:  8
# Finished 14.00 percent in 1.703149 s Acceptance rate = 0.392833Adding DE jump with weight 50
# Finished 98.00 percent in 13.635269 s Acceptance rate = 0.149286
# Run Complete
# Calculating weights for iteration:  8
# Calculating ess for iteration:  8
# ITERATION:  9
# Finished 14.00 percent in 2.424654 s Acceptance rate = 0.889571Adding DE jump with weight 50
# Finished 98.00 percent in 14.017460 s Acceptance rate = 0.637988
# Run Complete
# Calculating weights for iteration:  9
# Calculating ess for iteration:  9
# ITERATION:  10
# Finished 14.00 percent in 1.666276 s Acceptance rate = 0.934714Adding DE jump with weight 50
# Finished 98.00 percent in 11.492670 s Acceptance rate = 0.586898
# Run Complete
# Calculating weights for iteration:  10
# Calculating ess for iteration:  10
# ITERATION:  11
# Finished 14.00 percent in 1.724136 s Acceptance rate = 0.753714Adding DE jump with weight 50
# Finished 98.00 percent in 10.957095 s Acceptance rate = 0.319612
# Run Complete
# Calculating weights for iteration:  11
# Calculating ess for iteration:  11
# ITERATION:  12
# Finished 14.00 percent in 1.730969 s Acceptance rate = 0.369857Adding DE jump with weight 50
# Finished 98.00 percent in 12.175130 s Acceptance rate = 0.200592
# Run Complete
# Calculating weights for iteration:  12
# Calculating ess for iteration:  12
# ITERATION:  13
# Finished 14.00 percent in 1.787351 s Acceptance rate = 0.934429Adding DE jump with weight 50
# Finished 98.00 percent in 11.516056 s Acceptance rate = 0.456514
# Run Complete
# Calculating weights for iteration:  13
# Calculating ess for iteration:  13
# ITERATION:  14
# Finished 14.00 percent in 1.697419 s Acceptance rate = 0.410286Adding DE jump with weight 50
# Finished 98.00 percent in 10.303960 s Acceptance rate = 0.151449
# Run Complete
# Calculating weights for iteration:  14
# Calculating ess for iteration:  14
# ITERATION:  15
# Finished 14.00 percent in 2.203376 s Acceptance rate = 0.0931429Adding DE jump with weight 50
# Finished 98.00 percent in 11.111793 s Acceptance rate = 0.0671224
# Run Complete
# Calculating weights for iteration:  15
# Calculating ess for iteration:  15
# ITERATION:  16
# Finished 14.00 percent in 1.754430 s Acceptance rate = 0.936571Adding DE jump with weight 50
# Finished 98.00 percent in 12.083243 s Acceptance rate = 0.770837
# Run Complete
# Calculating weights for iteration:  16
# Calculating ess for iteration:  16
# ITERATION:  17
# Finished 14.00 percent in 2.045666 s Acceptance rate = 0.934143Adding DE jump with weight 50
# Finished 98.00 percent in 11.286276 s Acceptance rate = 0.769327
# Run Complete
# Calculating weights for iteration:  17
# Calculating ess for iteration:  17
# ITERATION:  18
# Finished 14.00 percent in 1.660914 s Acceptance rate = 0.850571Adding DE jump with weight 50
# Finished 98.00 percent in 11.819951 s Acceptance rate = 0.288367
# Run Complete
# Calculating weights for iteration:  18
# Calculating ess for iteration:  18
# ITERATION:  19
# Finished 14.00 percent in 1.468753 s Acceptance rate = 0.229429Adding DE jump with weight 50
# Finished 98.00 percent in 9.995814 s Acceptance rate = 0.120143
# Run Complete
# Calculating weights for iteration:  19
# Calculating ess for iteration:  19
# ITERATION:  20
# Finished 14.00 percent in 1.435261 s Acceptance rate = 0.893429Adding DE jump with weight 50
# Finished 98.00 percent in 10.797031 s Acceptance rate = 0.711816
# Run Complete
# Calculating weights for iteration:  20
# Calculating ess for iteration:  20
# ITERATION:  21
# Finished 14.00 percent in 1.528982 s Acceptance rate = 0.935714Adding DE jump with weight 50
# Finished 98.00 percent in 10.101530 s Acceptance rate = 0.721163
# Run Complete
# Calculating weights for iteration:  21
# Calculating ess for iteration:  21
# ITERATION:  22
# Finished 14.00 percent in 1.440742 s Acceptance rate = 0.216714Adding DE jump with weight 50
# Finished 98.00 percent in 9.511452 s Acceptance rate = 0.118469
# Run Complete
# Calculating weights for iteration:  22
# Calculating ess for iteration:  22
# ITERATION:  23
# Finished 14.00 percent in 1.813278 s Acceptance rate = 0.892571Adding DE jump with weight 50
# Finished 98.00 percent in 10.394429 s Acceptance rate = 0.463102
# Run Complete
# Calculating weights for iteration:  23
# Calculating ess for iteration:  23
# ITERATION:  24
# Finished 14.00 percent in 1.447631 s Acceptance rate = 0.391714Adding DE jump with weight 50
# Finished 98.00 percent in 11.199163 s Acceptance rate = 0.192184
# Run Complete
# Calculating weights for iteration:  24
# Calculating ess for iteration:  24
# ITERATION:  25
# Finished 14.00 percent in 1.421146 s Acceptance rate = 0.303571Adding DE jump with weight 50
# Finished 98.00 percent in 10.523785 s Acceptance rate = 0.164776
# Run Complete
# Calculating weights for iteration:  25
# Calculating ess for iteration:  25
# ITERATION:  26
# Finished 14.00 percent in 2.014298 s Acceptance rate = 0.934286Adding DE jump with weight 50
# Finished 98.00 percent in 11.631864 s Acceptance rate = 0.827347
# Run Complete
# Calculating weights for iteration:  26
# Calculating ess for iteration:  26
# ITERATION:  27
# Finished 14.00 percent in 1.842044 s Acceptance rate = 0.807571Adding DE jump with weight 50
# Finished 98.00 percent in 10.603472 s Acceptance rate = 0.313857
# Run Complete
# Calculating weights for iteration:  27
# Calculating ess for iteration:  27
# ITERATION:  28
# Finished 14.00 percent in 1.590778 s Acceptance rate = 0.934714Adding DE jump with weight 50
# Finished 98.00 percent in 11.839443 s Acceptance rate = 0.758184
# Run Complete
# Calculating weights for iteration:  28
# Calculating ess for iteration:  28
# ITERATION:  29
# Finished 14.00 percent in 2.017414 s Acceptance rate = 0.515571Adding DE jump with weight 50
# Finished 98.00 percent in 10.974444 s Acceptance rate = 0.241041
# Run Complete
# Calculating weights for iteration:  29
# Calculating ess for iteration:  29
# ITERATION:  30
# Finished 14.00 percent in 1.758356 s Acceptance rate = 0.765571Adding DE jump with weight 50
# Finished 98.00 percent in 11.190506 s Acceptance rate = 0.281306
# Run Complete
# Calculating weights for iteration:  30
# Calculating ess for iteration:  30
# ITERATION:  31
# Finished 14.00 percent in 1.462867 s Acceptance rate = 0.0911429Adding DE jump with weight 50
# Finished 98.00 percent in 9.425700 s Acceptance rate = 0.0759184
# Run Complete
# Calculating weights for iteration:  31
# Calculating ess for iteration:  31
# ITERATION:  32
# Finished 14.00 percent in 1.544395 s Acceptance rate = 0.8235Adding DE jump with weight 50
# Finished 98.00 percent in 9.973849 s Acceptance rate = 0.363204
# Run Complete
# Calculating weights for iteration:  32
# Calculating ess for iteration:  32
# ITERATION:  33
# Finished 14.00 percent in 1.824057 s Acceptance rate = 0.933143Adding DE jump with weight 50
# Finished 98.00 percent in 10.854349 s Acceptance rate = 0.768918
# Run Complete
# Calculating weights for iteration:  33
# Calculating ess for iteration:  33
# ITERATION:  34
# Finished 14.00 percent in 1.678478 s Acceptance rate = 0.842286Adding DE jump with weight 50
# Finished 98.00 percent in 9.958923 s Acceptance rate = 0.578388
# Run Complete
# Calculating weights for iteration:  34
# Calculating ess for iteration:  34
# ITERATION:  35
# Finished 14.00 percent in 1.485235 s Acceptance rate = 0.621571Adding DE jump with weight 50
# Finished 98.00 percent in 12.072750 s Acceptance rate = 0.261592
# Run Complete
# Calculating weights for iteration:  35
# Calculating ess for iteration:  35
# ITERATION:  36
# Finished 14.00 percent in 1.677352 s Acceptance rate = 0.391714Adding DE jump with weight 50
# Finished 98.00 percent in 11.084680 s Acceptance rate = 0.370429
# Run Complete
# Calculating weights for iteration:  36
# Calculating ess for iteration:  36
# ITERATION:  37
# Finished 14.00 percent in 1.655759 s Acceptance rate = 0.936714Adding DE jump with weight 50
# Finished 98.00 percent in 11.634729 s Acceptance rate = 0.813306
# Run Complete
# Calculating weights for iteration:  37
# Calculating ess for iteration:  37
# ITERATION:  38
# Finished 14.00 percent in 1.653219 s Acceptance rate = 0.935429Adding DE jump with weight 50
# Finished 98.00 percent in 12.234534 s Acceptance rate = 0.807857
# Run Complete
# Calculating weights for iteration:  38
# Calculating ess for iteration:  38
# ITERATION:  39
# Finished 14.00 percent in 1.967981 s Acceptance rate = 0.933286Adding DE jump with weight 50
# Finished 98.00 percent in 12.195657 s Acceptance rate = 0.317898
# Run Complete
# Calculating weights for iteration:  39
# Calculating ess for iteration:  39
# ITERATION:  40
# Finished 14.00 percent in 2.518182 s Acceptance rate = 0.772571Adding DE jump with weight 50
# Finished 98.00 percent in 15.975239 s Acceptance rate = 0.279204
# Run Complete
# Calculating weights for iteration:  40
# Calculating ess for iteration:  40
# ITERATION:  41
# Finished 14.00 percent in 1.863039 s Acceptance rate = 0.891667Adding DE jump with weight 50
# Finished 98.00 percent in 12.128627 s Acceptance rate = 0.352286
# Run Complete
# Calculating weights for iteration:  41
# Calculating ess for iteration:  41
# ITERATION:  42
# Finished 14.00 percent in 2.022455 s Acceptance rate = 0.341857Adding DE jump with weight 50
# Finished 98.00 percent in 11.111745 s Acceptance rate = 0.148306
# Run Complete
# Calculating weights for iteration:  42
# Calculating ess for iteration:  42
# ITERATION:  43
# Finished 14.00 percent in 2.120050 s Acceptance rate = 0.664286Adding DE jump with weight 50
# Finished 98.00 percent in 13.702986 s Acceptance rate = 0.270163
# Run Complete
# Calculating weights for iteration:  43
# Calculating ess for iteration:  43
# ITERATION:  44
# Finished 14.00 percent in 1.738830 s Acceptance rate = 0.892143Adding DE jump with weight 50
# Finished 98.00 percent in 12.859757 s Acceptance rate = 0.326816
# Run Complete
# Calculating weights for iteration:  44
# Calculating ess for iteration:  44
# ITERATION:  45
# Finished 14.00 percent in 1.576946 s Acceptance rate = 0.891286Adding DE jump with weight 50
# Finished 98.00 percent in 10.366093 s Acceptance rate = 0.356469
# Run Complete
# Calculating weights for iteration:  45
# Calculating ess for iteration:  45
# ITERATION:  46
# Finished 14.00 percent in 1.482666 s Acceptance rate = 0.0631429Adding DE jump with weight 50
# Finished 98.00 percent in 9.557808 s Acceptance rate = 0.0633265
# Run Complete
# Calculating weights for iteration:  46
# Calculating ess for iteration:  46
# ITERATION:  47
# Finished 14.00 percent in 1.451558 s Acceptance rate = 0.0807143Adding DE jump with weight 50
# Finished 98.00 percent in 9.504262 s Acceptance rate = 0.0686122
# Run Complete
# Calculating weights for iteration:  47
# Calculating ess for iteration:  47
# ITERATION:  48
# Finished 14.00 percent in 1.637236 s Acceptance rate = 0.0532857Adding DE jump with weight 50
# Finished 98.00 percent in 9.824447 s Acceptance rate = 0.0606531
# Run Complete
# Calculating weights for iteration:  48
# Calculating ess for iteration:  48
# ITERATION:  49
# Finished 14.00 percent in 1.482722 s Acceptance rate = 0.933857Adding DE jump with weight 50
# Finished 98.00 percent in 10.158886 s Acceptance rate = 0.764796
# Run Complete
# Calculating weights for iteration:  49
# Calculating ess for iteration:  49

# %%
PTchain.shape
# Out:
# (49000, 2)

# %%
print('Average AFER: ', np.mean(AFERhatPT))
print('Average # of Modes Discovered: ', np.mean(ndisModesPT))
print('Average neff: ', np.mean(hatIATPT))
print('Average x_1: ', np.mean(np.mean(np.mean(sample_PT1,0))) )
print('Average x_2: ', np.mean(np.mean(np.mean(sample_PT2,0))) )
# Out:
# Average AFER:  0.9948983661497124
# Average # of Modes Discovered:  14.44
# Average neff:  151.42532829440697
# Average x_1:  4.450316671395477
# Average x_2:  5.304127225836578

# %%
plt.plot(sample_PT1[bi:30000, 46:])
# Out:
# [<matplotlib.lines.Line2D at 0x14020a550>,
#  <matplotlib.lines.Line2D at 0x13ffd3ac0>,
#  <matplotlib.lines.Line2D at 0x13ffd39a0>,
#  <matplotlib.lines.Line2D at 0x13ffd3f40>]

# %%
sns.set()
plt.plot(PTchain[5000:,0])
plt.xlabel( r'$t$' )
plt.ylabel( 'State Space' )
plt.title( r'PT Case B '+r'$x_1$'  )
plt.savefig('traceplot-PTBx1.png', dpi=500)    
plt.show()

# %%
sns.set()
plt.plot(PTchain[5000:,1])
plt.xlabel( r'$t$' )
plt.ylabel( 'State Space' )
plt.title( r'PT Case B '+r'$x_2$' )
plt.savefig('traceplot-PTBx2.png', dpi=500)    
plt.show()

# %%
xx,yy,Z= fpoints(f= logf ,args=(0,), theta=(), pars=(),
                  lb= np.array([0,0]), upb= np.array([10, 10]) , m=200 ) #takes time :)

# %%
sns.set()
plt.contour( xx, yy, -Z, 10, colors='b' )
plt.scatter( PTchain[:, 0 ],PTchain[:, 1 ], s=0.5 )
plt.xlabel( r'$x_1$' )
plt.ylabel( r'$x_2$' )
plt.title( r'PT Contours case B' )
plt.savefig('PTContoursB.png', dpi=500)    
plt.show()

# %%
sns.set()
plt.contour( xx, yy, -Z, 15, colors='b' )
#plt.scatter( PTchain[:, 0 ],PTchain[:, 1 ], s=0.5 )
plt.xlabel( r'$x_1$' )
plt.ylabel( r'$x_2$' )
plt.title( r'PT Contours case B' )
plt.savefig('ex-ContoursCaseB.png', dpi=500)    
plt.show()

# %%
#Expected

e=np.zeros(2)
for i in range(20):
   e+=real_weights[i]*mu[i]


print(e)
# Out:
# [4.68761415 5.03023534]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-3a4507ae9dc5> in <module>
# ----> 1 real_weights*mu
#
# ValueError: operands could not be broadcast together with shapes (20,) (20,2)
